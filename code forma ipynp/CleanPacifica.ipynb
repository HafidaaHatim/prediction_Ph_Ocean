# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataKNN.csv')

# %%
df
# Out:
#         CTDTMP [ITS-90]  OXYGEN [UMOL/KG]  CTDSAL [PSS-78]  TCARBN [UMOL/KG]  \
# 0                 4.547            119.10        34.547339           2286.68
# 1                 4.533            100.64        34.497660           2290.58
# 2                 4.536            130.80        34.446640           2282.86
# 3                 4.536            130.80        34.446640           2282.86
# 4                 4.536            130.80        34.446640           2282.86
# ...                 ...               ...              ...               ...
# 277318            3.494             67.60        34.432999           2290.04
# 277319            2.898             82.60        34.512001           2325.14
# 277320            2.621             99.60        34.558998           2342.30
# 277321            2.339            115.70        34.598000           2347.40
# 277322            2.147            124.90        34.618000           2331.46
#
#         ALKALI [UMOL/KG]  PHSPHT [UMOL/KG]  SILCAT [UMOL/KG]  CTDPRS [DBAR]  \
# 0                2356.26             2.824            70.516          997.4
# 1                2348.82             2.744            71.046          998.3
# 2                2339.48             2.532            62.012          998.7
# 3                2339.48             2.532            62.012          998.7
# 4                2339.48             2.532            62.012          998.7
# ...                  ...               ...               ...            ...
# 277318           2359.24             2.880           120.580         1098.0
# 277319           2374.28             2.780           129.890         1299.0
# 277320           2384.66             2.770           133.730         1499.0
# 277321           2404.94             2.710           136.900         1702.0
# 277322           2402.02             2.650           138.430         1870.0
#
#         NITRAT [UMOL/KG]        PH
# 0                 37.126  7.552423
# 1                 38.908  7.518387
# 2                 35.762  7.514944
# 3                 35.762  7.514944
# 4                 35.762  7.514944
# ...                  ...       ...
# 277318            41.750  7.565329
# 277319            40.660  7.508111
# 277320            40.110  7.487689
# 277321            39.560  7.536210
# 277322            38.750  7.576535
#
# [277323 rows x 10 columns]

# %%
df= df.drop(['ALKALI [UMOL/KG]','CTDPRS [DBAR]','CTDSAL [PSS-78]'], axis=1)

# %%
df
# Out:
#         CTDTMP [ITS-90]  OXYGEN [UMOL/KG]  TCARBN [UMOL/KG]  PHSPHT [UMOL/KG]  \
# 0                 4.547            119.10           2286.68             2.824
# 1                 4.533            100.64           2290.58             2.744
# 2                 4.536            130.80           2282.86             2.532
# 3                 4.536            130.80           2282.86             2.532
# 4                 4.536            130.80           2282.86             2.532
# ...                 ...               ...               ...               ...
# 277318            3.494             67.60           2290.04             2.880
# 277319            2.898             82.60           2325.14             2.780
# 277320            2.621             99.60           2342.30             2.770
# 277321            2.339            115.70           2347.40             2.710
# 277322            2.147            124.90           2331.46             2.650
#
#         SILCAT [UMOL/KG]  NITRAT [UMOL/KG]        PH
# 0                 70.516            37.126  7.552423
# 1                 71.046            38.908  7.518387
# 2                 62.012            35.762  7.514944
# 3                 62.012            35.762  7.514944
# 4                 62.012            35.762  7.514944
# ...                  ...               ...       ...
# 277318           120.580            41.750  7.565329
# 277319           129.890            40.660  7.508111
# 277320           133.730            40.110  7.487689
# 277321           136.900            39.560  7.536210
# 277322           138.430            38.750  7.576535
#
# [277323 rows x 7 columns]

# %%
corr_matrix = df.corr()

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
fig=plt.gcf()
fig.set_size_inches(16,9)
plt.show()

# %%
df.to_csv('PacificaClean.csv',index=False)
